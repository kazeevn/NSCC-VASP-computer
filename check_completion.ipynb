# %%
import pandas as pd

# %%
data = pd.read_csv("Mirage-14.csv.gz", index_col="material_id")

# %%
frozenset(range(data.index.max()+1)) - frozenset(data.index)
# Out:
# frozenset({66,
#            81,
#            104,
#            233,
#            250,
#            287,
#            316,
#            373,
#            403,
#            424,
#            550,
#            557,
#            594,
#            638,
#            724,
#            794,
#            966})
